# %%
from scipy.stats import ks_1samp

# %%
# %run incl_hist.py
# Out:
# 2 sample KS statistic: 0.184556, p value: 0.013259
# 1 sample KS statistic: 0.192866, p value: 0.008055
# 1 sample KS statistic: 0.192866, p value: 0.008055
# KstestResult(statistic=0.19286646340899186, pvalue=0.008055011916087313)
# /orange/adamginsburg/orion/jaotter_git/flux_plots/incl_hist.py:94: RuntimeWarning: invalid value encountered in arccos
#   inclination = np.arccos((minor**2 - (scaleheight/distance_pc)**2)**0.5/major)
